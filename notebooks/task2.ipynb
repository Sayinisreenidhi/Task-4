# %%
import os

print("sales_by_category:", os.path.getsize("sales_by_category.png"))
print("sales_vs_profit:", os.path.getsize("sales_vs_profit.png"))
print("correlation_heatmap:", os.path.getsize("correlation_heatmap.png"))
# Out:
# sales_by_category: 25666
# sales_vs_profit: 23393
# correlation_heatmap: 28414

# %%
category_sales = df.groupby("Category")["Sales"].sum().reset_index()

table_html = category_sales.to_html(index=False)

html = f"""
<html>
<head>
<title>Superstore Dashboard</title>

<style>
body {{
    font-family: Arial, sans-serif;
    background: linear-gradient(to right, #ff9966, #ff5e62);
    text-align: center;
    padding-top: 30px;
}}

.dashboard-box {{
    width: 600px;
    margin: auto;
    background: white;
    padding: 20px;
    border-radius: 10px;
    box-shadow: 0px 4px 15px rgba(0,0,0,0.3);
}}

table {{
    width: 100%;
    border-collapse: collapse;
}}

th {{
    background-color: #4CAF50;
    color: white;
    padding: 10px;
}}

td {{
    padding: 10px;
    border: 1px solid #ddd;
}}

h1 {{
    color: white;
}}
</style>

</head>

<body>

<h1>📊 Superstore Dashboard</h1>

<div class="dashboard-box">
    {table_html}
</div>

</body>
</html>
"""

with open("dashboard/dashboard.html", "w", encoding="utf-8") as f:
    f.write(html)

print("Dashboard saved successfully!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 category_sales = df.groupby("Category")["Sales"].sum().reset_index()
#       2
#       3 table_html = category_sales.to_html(index=False)
#       4
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#display charts
# %matplotlib inline
df = pd.read_csv("sample_dataset.csv", encoding="latin-1")

df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
import os

print(os.listdir())
# Out:
# ['.git', 'analysis_output.png.png', 'bar_chart.png.png', 'cleared_dataset.csv', 'correlation_heatmap.png', 'dashboard', 'dataset.csv', 'discount_vs_profit.png', 'monthly sales trend.png', 'pie_chart.png.png', 'profit_by_region.png', 'README.md', 'sales_by_category.png', 'sales_histogram.png', 'sales_vs_profit.png', 'sample_dataset.csv', 'segment_analysis.sql', 'superstore.db', 'Task1.ipynb', 'task2.ipynb', 'top_10_products_sales.png', 'top_products.png']

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#Load dataset
df = pd.read_csv("sample_dataset.csv", encoding="latin-1")


#show first rows
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
import os
print(os.path.exists("dashboard/dashboard.html"))
# Out:
# True

# %%
import os

os.makedirs("dashboard", exist_ok=True)

html = """
<html>
<head>
    <title>Superstore Dashboard</title>
</head>
<body>
    <h1>Superstore Dashboard</h1>

    <h2>Sales Histogram</h2>
    <img src="../sales_histogram.png" width="600">

    <h2>Sales by Category</h2>
    <img src="../sales_by_category.png" width="600">

    <h2>Profit by Region</h2>
    <img src="../profit_by_region.png" width="600">

    <h2>Sales vs Profit</h2>
    <img src="../sales_vs_profit.png" width="600">

    <h2>Correlation Heatmap</h2>
    <img src="../correlation_heatmap.png" width="600">
</body>
</html>
"""

with open("dashboard/dashboard.html", "w", encoding="utf-8") as f:
    f.write(html)

print("🎉 Dashboard saved successfully!")
# Out:
# 🎉 Dashboard saved successfully!

# %%
os.makedirs("dashboard", exist_ok=True)

html = """
<html>
<head>
    <title>Superstore Dashboard</title>
</head>
<body>
    <h1>Superstore Dashboard</h1>

    <h2>Sales Histogram</h2>
    <img src="../sales_histogram.png" width="600">

    <h2>Sales by Category</h2>
    <img src="../sales_by_category.png" width="600">

    <h2>Profit by Region</h2>
    <img src="../profit_by_region.png" width="600">

    <h2>Sales vs Profit</h2>
    <img src="../sales_vs_profit.png" width="600">

    <h2>Correlation Heatmap</h2>
    <img src="../correlation_heatmap.png" width="600">
</body>
</html>
"""

with open("dashboard/dashboard.html", "w", encoding="utf-8") as f:
    f.write(html)

print("🎉 Dashboard saved successfully!")
# Out:
# 🎉 Dashboard saved successfully!

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x='Discount', y='Profit')
plt.title('Discount vs Profit')
plt.show()

# %%
top_products = df.groupby('Product Name')['Sales'].sum().sort_values(ascending=False).head(10)

top_products.plot(kind="barh")
plt.title("Top 10 Products by Sales")
plt.xlabel("Sales")
plt.tight_layout()
plt.savefig("top_products.png")
plt.show()

# %%
segment_sales = df.groupby('Segment')['Sales'].sum()

plt.figure(figsize=(6,6))
segment_sales.plot(kind='pie', autopct='%1.1f%%')
plt.title('Sales by Segment')
plt.ylabel('')
plt.show()

# %%
top_products = df.groupby('Product Name')['Sales'].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(10,6))
top_products.plot(kind='bar')
plt.title('Top 10 Products by Sales')
plt.ylabel('Sales')
plt.xticks(rotation=75)
plt.show()

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

monthly_sales = df.groupby(df['Order Date'].dt.to_period('M'))['Sales'].sum()

monthly_sales.plot(figsize=(12,6))
plt.title('Monthly Sales Trend')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.grid(True)
plt.show()

# %%
import seaborn as sns

corr = df[['Sales','Quantity','Discount','Profit']].corr()

plt.figure(figsize=(6,4))
sns.heatmap(corr, annot=True)
plt.title('Correlation Heatmap')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.scatter(df['Sales'], df['Profit'])
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.title('Sales vs Profit')
plt.show()

# %%
region_profit = df.groupby('Region')['Profit'].sum()

region_profit.plot(kind='bar')
plt.title('Profit by Region')
plt.xlabel('Region')
plt.ylabel('Profit')
plt.show()

# %%
category_sales = df.groupby('Category')['Sales'].sum()

category_sales.plot(kind='bar')
plt.title('Sales by Category')
plt.xlabel('Category')
plt.ylabel('Total Sales')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.hist(df['Sales'], bins=20)
plt.title('Sales Distribution')
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.show()

# %%
print(df.columns)
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
import pandas as pd

df = pd.read_csv("cleared_dataset.csv")

print(df.head())
print(df.info())
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...
